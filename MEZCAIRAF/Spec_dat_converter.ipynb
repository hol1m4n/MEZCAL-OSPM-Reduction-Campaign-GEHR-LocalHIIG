# %%
import os
import shutil
import ast
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from joblib import Parallel, delayed
import pyfiglet

# %%
parent  = os.path.dirname('/home/hollman/MEZCAL-OSPM-Reduction-Campaign-GEHR-LocalHIIG/')

noches = [ f for f in os.listdir(parent) if '2019' in f or '2020' in f or '2021' in f or '2022' in f or '2023' in f or '2024' in f or '2025' in f or '2026' in f ]
noches.sort()

noches
# Out:
# ['2022-marzo-N1',
#  '2022-marzo-N2',
#  '2022-marzo-N3',
#  '2022-marzo-N4',
#  '2022-marzo-N5',
#  '2023-junio-N1',
#  '2023-junio-N2',
#  '2023-junio-N3',
#  '2023-junio-N4',
#  '2023-junio-N5',
#  '2023-junio-N6',
#  '2023-noviembre-N1',
#  '2024-marzo-N3']
